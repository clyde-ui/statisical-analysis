# %%
import pandas as pd
import numpy as np

# %%
# !pip install pandas

# %% [markdown]
# **PANDAS**
#
# - It is a python library used for data manipulation and analysis.
# - There are two core objects in pandas.:
#
#    **pandas series**
#
#     It is a one dimension array that can hold data of any type.
#
#    **dataframes**
#
#     It is a two dimensional array with both rows and columns label.

# %% [markdown]
# ## <u> Pandas Module Breakdown <u>
#
# - *creating,reading and writing data.*
#
#
# - *indexing,selection and assigning.*
#
#
# - *summary functions.*
#
#
# - *grouping and sorting*
#
#
# - *saving in csv format.*

# %% [markdown]
# **1.CREATING DATA IN PANDAS**

# %% [markdown]
# - We create series by passing a list or a dictionary in pd.series.

# %%
mylist=[1,2.0,3,5,6]
mylist
# Out:
# [1, 2.0, 3, 5, 6]

# %%
import pandas as pd
my_series=pd.Series([1,2,3,4,5])
my_series.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
type(my_series)
# Out:
# pandas.core.series.Series

# %%
my_series.dtype
# Out:
# dtype('int64')

# %%
my_series.ndim
# Out:
# 1

# %%
type(my_series)
# Out:
# pandas.core.series.Series

# %%
dict={"company":["jkuat","bidco","temco"],
     "wealth(M)":[20,30,50]}
dict
# Out:
# {'company': ['jkuat', 'bidco', 'temco'], 'wealth(M)': [20, 30, 50]}

# %%
mydict={"faith":"samsung","class":"python","school":"jkuat"}
print(mydict)
print(type(mydict))
# Out:
# {'faith': 'samsung', 'class': 'python', 'school': 'jkuat'}
# <class 'dict'>

# %%
series=pd.Series(dict)
series
# Out:
# company      [jkuat, bidco, temco]
# wealth(M)             [20, 30, 50]
# dtype: object

# %%
series.dtype
# Out:
# dtype('O')

# %%
type(series)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Data frames
#
# - For us to create a data frame we can pass only a dictionary ie the dict created above

# %%
data=pd.DataFrame(dict)
print(data)
# Out:
#   company  wealth(M)
# 0   jkuat         20
# 1   bidco         30
# 2   temco         50

# %%
data.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
dict={"tecno":[5,6,7,3],"samsung":[4,8,4,3]}
print(dict)
# Out:
# {'tecno': [5, 6, 7, 3], 'samsung': [4, 8, 4, 3]}

# %%
data=pd.DataFrame(dict)
print(data)
# Out:
#    tecno  samsung
# 0      5        4
# 1      6        8
# 2      7        4
# 3      3        3

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %% [markdown]
# - **Changing the Index from `0,1,2,3` to `"Gate A","Gate B","Gate C","Gate D"`**

# %%
phones=pd.DataFrame(dict,index=["Gate A","Gate B","Gate C","Gate D"])
print(phones)
# Out:
#         tecno  samsung
# Gate A      5        4
# Gate B      6        8
# Gate C      7        4
# Gate D      3        3

# %%
print(phones.index)
# Out:
# Index(['Gate A', 'Gate B', 'Gate C', 'Gate D'], dtype='object')

# %% [markdown]
# - Combining everything in one line

# %%
mydataframe=pd.DataFrame({"tecno":[5,6,7,3],"samsung":[4,8,4,3]},index=["Gate A","Gate B","Gate C","Gate D"])
print(mydataframe)
# Out:
#         tecno  samsung
# Gate A      5        4
# Gate B      6        8
# Gate C      7        4
# Gate D      3        3

# %%
mydataframe.index
# Out:
# Index(['Gate A', 'Gate B', 'Gate C', 'Gate D'], dtype='object')

# %% [markdown]
# ### **3.  Reading(Importing) and writing data(exporting) in pandas**

# %% [markdown]
# When reading data files in pandas its important to read it with its format.

# %% [markdown]
# **Examples of the files formats and how we read them**

# %% [raw]
# excel=pd.read_xlsx("data.xlsx") ##We have to install openpyxyl
# HTML=pd.read_html("data.html")
# tables=pd.read_table("data.table")
# csv=pd.read_csv("name.csv")#comma separated values
# txt=pd.read_csv("name.txt") #tab delimited

# %% [markdown]
# NB:It is important to note that a singlebackslash does not work when specifying the file path. You need to either change it to forward slash or add one more backslash like below

# %% [markdown]
# <b>1. Import .csv files</u>

# %% [markdown]
# **Importing .csv files(when file not uploaded)**

# %%
data=pd.read_csv("df.csv")
data
# Out:
#      County  Population   Area      count
# 0   Nairobi   4397073.0    704  4397073.0
# 1    Kisumu   1155574.0   2085  1155574.0
# 2   Mombasa   1208333.0    220  1208333.0
# 3   Bungoma   1670570.0   3024  1670570.0
# 4   Mandera    867457.0  25942   867457.0
# 5   Turkana    926976.0  68233   926976.0
# 6  Marsabit    459785.0  70944   459785.0
# 7     Nyeri    759164.0   3325   759164.0
# 8   Nairobi   4397073.0    704  4397073.0
# 9      Embu         NaN   2821        NaN

# %%
data=pd.read_csv("df.csv")
data
# Out:
#    Unnamed: 0 Company   Person  Sales  profit
# 0           0    GOOG      Sam    200     200
# 1           1    GOOG  Charlie    120     120
# 2           2    MSFT      Amy    340     340
# 3           3    MSFT  Vanessa    124     124
# 4           4      FB     Carl    243     243
# 5           5      FB    Sarah    350     350

# %%
data3=pd.read_csv("companies.csv")
data3
# Out:
#   Company   Person  Sales  profit
# 0    GOOG      Sam    200     200
# 1    GOOG  Charlie    120     120
# 2    MSFT      Amy    340     340
# 3    MSFT  Vanessa    124     124
# 4      FB     Carl    243     243
# 5      FB    Sarah    350     350

# %%
data7=pd.read_csv("F:\\aaaaaaa\\python\\DATA SCIENCE 1\\everything\\pandas\\df.csv")
data7
# Out:
#      County  Population   Area      count
# 0   Nairobi   4397073.0    704  4397073.0
# 1    Kisumu   1155574.0   2085  1155574.0
# 2   Mombasa   1208333.0    220  1208333.0
# 3   Bungoma   1670570.0   3024  1670570.0
# 4   Mandera    867457.0  25942   867457.0
# 5   Turkana    926976.0  68233   926976.0
# 6  Marsabit    459785.0  70944   459785.0
# 7     Nyeri    759164.0   3325   759164.0
# 8   Nairobi   4397073.0    704  4397073.0
# 9      Embu         NaN   2821        NaN

# %%
import pandas as pd
data=pd.read_csv("companies.csv") ##importing dataset
data
# Out:
#   Company   Person  Sales  profit
# 0    GOOG      Sam    200     200
# 1    GOOG  Charlie    120     120
# 2    MSFT      Amy    340     340
# 3    MSFT  Vanessa    124     124
# 4      FB     Carl    243     243
# 5      FB    Sarah    350     350

# %% [markdown]
# **exporting** ASSIGNMENT 1

# %%
data.to_csv("data2.csv")

# %%
data.to_csv("data2.csv", columns=["Area","count"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 data.to_csv("data2.csv", columns=["Area","count"])
#
# File ~\dist\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\dist\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File ~\dist\Lib\site-packages\pandas\io\formats\format.py:995, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     992 else:
#     993     created_buffer = False
# --> 995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#     998     sep=sep,
#     999     encoding=encoding,
#    1000     errors=errors,
#    1001     compression=compression,
#    1002     quoting=quoting,
#    1003     cols=columns,
#    1004     index_label=index_label,
#    1005     mode=mode,
#    1006     chunksize=chunksize,
#    1007     quotechar=quotechar,
#    1008     date_format=date_format,
#    1009     doublequote=doublequote,
#    1010     escapechar=escapechar,
#    1011     storage_options=storage_options,
#    1012     formatter=self.fmt,
#    1013 )
#    1014 csv_formatter.save()
#    1016 if created_buffer:
#
# File ~\dist\Lib\site-packages\pandas\io\formats\csvs.py:98, in CSVFormatter.__init__(self, formatter, path_or_buf, sep, cols, index_label, mode, encoding, errors, compression, quoting, lineterminator, chunksize, quotechar, date_format, doublequote, escapechar, storage_options)
#      96 self.lineterminator = lineterminator or os.linesep
#      97 self.date_format = date_format
# ---> 98 self.cols = self._initialize_columns(cols)
#      99 self.chunksize = self._initialize_chunksize(chunksize)
#
# File ~\dist\Lib\site-packages\pandas\io\formats\csvs.py:167, in CSVFormatter._initialize_columns(self, cols)
#     165     else:
#     166         cols = list(cols)
# --> 167     self.obj = self.obj.loc[:, cols]
#     169 # update columns to include possible multiplicity of dupes
#     170 # and make sure cols is just a list of labels
#     171 new_cols = self.obj.columns
#
# File ~\dist\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\dist\Lib\site-packages\pandas\core\indexing.py:1377, in _LocIndexer._getitem_tuple(self, tup)
#    1374 if self._multi_take_opportunity(tup):
#    1375     return self._multi_take(tup)
# -> 1377 return self._getitem_tuple_same_dim(tup)
#
# File ~\dist\Lib\site-packages\pandas\core\indexing.py:1020, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#    1017 if com.is_null_slice(key):
#    1018     continue
# -> 1020 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#    1021 # We should never have retval.ndim < self.ndim, as that should
#    1022 #  be handled by the _getitem_lowerdim call above.
#    1023 assert retval.ndim == self.ndim
#
# File ~\dist\Lib\site-packages\pandas\core\indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# File ~\dist\Lib\site-packages\pandas\core\indexing.py:1360, in _LocIndexer._getitem_iterable(self, key, axis)
#    1357 self._validate_key(key, axis)
#    1359 # A collection of keys
# -> 1360 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1361 return self.obj._reindex_with_indexers(
#    1362     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1363 )
#
# File ~\dist\Lib\site-packages\pandas\core\indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1555 ax = self.obj._get_axis(axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File ~\dist\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\dist\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Area', 'count'], dtype='object')] are in the [columns]"

# %%
1. export the file data into following formarts
 a. stata----- .dta(pyreadstat(sas,spss and stata files))
 b. spss----- .sav
 c. sas-------.sas
 d. excel----- .xlsx
 e. r-------.Rdata

# %%
2. Import all the above files
3. imprt data from a url.

# %% [markdown]
# **If no header (title) in raw data file**

# %% [markdown]
# You need to include header = None option to tell Python there is no column name (header) in data.

# %% [raw]
# mydata= pd.read_csv("C:\\Users\\jkuat\\Data\\df2.csv",header=None)

# %% [markdown]
# <b>2. Import File from URL

# %% [raw]
# mydata = pd.read_csv("http://winterolympicsmedals.com//medals.csv")
# mydata

# %% [markdown]
# You don't need to perform additional steps to fetch data from URL. Simply put URL in read_csv() function (applicable only for CSV files stored in URL)

# %% [markdown]
# <b>3. Read Text File

# %% [markdown]
# We can use read_table() function to pull data from text file. We can also use read_csv() with sep= "\t" to read data from tab-separated file.

# %% [raw]
# mydata = pd.read_table("C:\\Users\\Deepanshu\\Desktop\\example2.txt")
# mydata = pd.read_csv("C:\\Users\\Deepanshu\\Desktop\\example2.txt", sep ="\t")

# %%
data4=pd.read_csv("F:\\aaaaaaa\\python\\DATA SCIENCE 1\\week 4 Pandas\\pandas data\\df5.txt", delim_whitespace=True) 
data4

# %% [markdown]
# <b>4. Read Excel File

# %% [markdown]
# The read_excel() function can be used to import excel data into Python.

# %% [raw]
# mydata = pd.read_excel("https://www.eia.gov/dnav/pet/hist_xls/RBRTEd.xlsx",sheetname="Data 1", skiprows=2)

# %% [markdown]
# If you do not specify name of sheet in sheetname= option, it would take by default first sheet.

# %% [markdown]
# <b>5. Read SAS File

# %% [markdown]
# We can import SAS data file by using read_sas() function.

# %% [raw]
# mydata4 = pd.read_sas('cars.sas7bdat')

# %% [markdown]
# f you have a large SAS File, you can try package named `pyreadstat` which is faster than pandas. It is equivalent to `haven` package in R which provides easy and fast way to read data from SAS, SPSS and Stata. To install this package, you can use the command `pip install pyreadstat`

# %% [markdown]
# <b> 6. Read Stata File

# %% [markdown]
# We can load Stata data file via read_stata() function.

# %% [raw]
# mydata41 = pd.read_stata('cars.dta')

# %% [markdown]
# `pyreadstat` package lets you to pull value labels from stata files.

# %% [raw]
# import pyreadstat
# df = pyreadstat.read_dta("cars.dta")

# %% [markdown]
# <b> 7. Import R Data File

# %% [markdown]
# Using pyreadr package, you can load .RData and .Rds format files which in general contains R data frame. You can install this package using the command below -

# %%
# !pip install pyreadr
# Out:
# Requirement already satisfied: pyreadr in c:\users\admin\dist\lib\site-packages (0.5.2)
# Requirement already satisfied: pandas>=1.2.0 in c:\users\admin\dist\lib\site-packages (from pyreadr) (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\admin\dist\lib\site-packages (from pandas>=1.2.0->pyreadr) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\dist\lib\site-packages (from pandas>=1.2.0->pyreadr) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\dist\lib\site-packages (from pandas>=1.2.0->pyreadr) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\dist\lib\site-packages (from pandas>=1.2.0->pyreadr) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\admin\dist\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2.0->pyreadr) (1.16.0)

# %% [markdown]
# With the use of `read_r( )` function, we can import R data format files.

# %% [raw]
# import pyreadr
# result = pyreadr.read_r('C:/Users/sampledata.RData')

# %% [markdown]
# <b>8.Import Data from SPSS File

# %% [raw]
# import pyreadstat
# df = pyreadstat.read_sav("file.sav", apply_value_formats=True)

# %% [markdown]
# If you don't want value labels, make apply_value_formats as False.

# %% [markdown]
# ### Exporting data from notebook(python pandas)

# %%
data.to_csv("cleandata.csv", columns=["Area","count"])

# %% [markdown]
# We will only focus on csv and excel formats in this level. Let start to read a data file with csv format

# %%
import pandas as pd
data=pd.read_csv("df.csv")
data
# Out:
#    Unnamed: 0 Company   Person  Sales  profit
# 0           0    GOOG      Sam    200     200
# 1           1    GOOG  Charlie    120     120
# 2           2    MSFT      Amy    340     340
# 3           3    MSFT  Vanessa    124     124
# 4           4      FB     Carl    243     243
# 5           5      FB    Sarah    350     350

# %%
data.dtypes
# Out:
# Unnamed: 0     int64
# Company       object
# Person        object
# Sales          int64
# profit         int64
# dtype: object

# %%
data2=pd.read_csv("df2.csv")
print(data2)
data2.dtypes
data2.Population.mean()
# Out:
#      County Population   Area    count
# 0   Nairobi    4397073    704  4397073
# 1    Kisumu    1155574   2085  1155574
# 2   Mombasa    1208333    220  1208333
# 3   Bungoma    1670570   3024  1670570
# 4   Mandera     867457  25942   867457
# 5   Turkana     926976  68233   926976
# 6  Marsabit     459785  70944   459785
# 7     Nyeri     759164   3325   759164
# 8   Nairobi    4397073    704  4397073
# 9      Embu          .   2821        .
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 4
#       2 print(data2)
#       3 data2.dtypes
# ----> 4 data2.Population.mean()
#
# File ~\dist\Lib\site-packages\pandas\core\series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\dist\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
#   12421         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422     )
#
# File ~\dist\Lib\site-packages\pandas\core\generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12373 nv.validate_func(name, (), kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File ~\dist\Lib\site-packages\pandas\core\series.py:6457, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6452     # GH#47500 - change to TypeError to match other methods
#    6453     raise TypeError(
#    6454         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6455         "with non-numeric dtypes."
#    6456     )
# -> 6457 return op(delegate, skipna=skipna, **kwds)
#
# File ~\dist\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~\dist\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~\dist\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#     723     count = cast(np.ndarray, count)
#
# File ~\dist\Lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#    1698 elif not (is_float(x) or is_integer(x) or is_complex(x)):
#    1699     if isinstance(x, str):
#    1700         # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701         raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702     try:
#    1703         x = float(x)
#
# TypeError: Could not convert string '43970731155574120833316705708674579269764597857591644397073.' to numeric

# %%
mydata7 = pd.read_csv("df.csv", nrows=5, usecols=(1,2,3))
mydata7
# Out:
#    Population   Area    count
# 0     4397073    704  4397073
# 1     1155574   2085  1155574
# 2     1208333    220  1208333
# 3     1670570   3024  1670570
# 4      867457  25942   867457

# %% [raw]
# ### ASSIGNMENT 2
# Write a code that will import the variables starts with...."p"
# Write a code that will import the variables that ends with...."t"
# Write a code that will import the variables that has ...."a"

# %% [markdown]
# Assignment

# %%
import pandas as pd
df = pd.read_csv('df2.csv')
columns_starting_with_p = [col for col in df.columns if col.startswith('P')]
df_filtered = df[columns_starting_with_p]
df_filtered.head()
# Out:
#   Population
# 0    4397073
# 1    1155574
# 2    1208333
# 3    1670570
# 4     867457

# %%
import pandas as pd
df = pd.read_csv('df2.csv')
columns_ending_with_t = [col for col in df.columns if col.endswith('t')]
df_filtered = df[columns_ending_with_t]
df_filtered.head()
# Out:
#      count
# 0  4397073
# 1  1155574
# 2  1208333
# 3  1670570
# 4   867457

# %%
import pandas as pd
df = pd.read_csv('df2.csv')
columns_with_a = [col for col in df.columns if 'a' in col]
df_filtered = df[columns_with_a]
df_filtered.head()
# Out:
#   Population   Area
# 0    4397073    704
# 1    1155574   2085
# 2    1208333    220
# 3    1670570   3024
# 4     867457  25942

# %% [markdown]
# nrows = 5 implies you want to import only first 5 rows and usecols= refers to specified columns you want to import.

# %%
df = pd.read_csv("df.csv", usecols=range(0,3))##upper limit not included 0:3
df
# Out:
#      County  Population   Area
# 0   Nairobi   4397073.0    704
# 1    Kisumu   1155574.0   2085
# 2   Mombasa   1208333.0    220
# 3   Bungoma   1670570.0   3024
# 4   Mandera    867457.0  25942
# 5   Turkana    926976.0  68233
# 6  Marsabit    459785.0  70944
# 7     Nyeri    759164.0   3325
# 8   Nairobi   4397073.0    704
# 9      Embu         NaN   2821

# %%
df.index ##Gives the
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %% [markdown]
# **Skip rows while importing**

# %% [markdown]
# Suppose you want to skip first 5 rows and wants to read data from 6th row (6th row would be a header row)

# %%
df3=pd.read_csv(("df.csv"),skiprows=2) #When we want to skip rows at the top of the data
df3
# Out:
#      Kisumu    1155574   2085  1155574.1
# 0   Mombasa  1208333.0    220  1208333.0
# 1   Bungoma  1670570.0   3024  1670570.0
# 2   Mandera   867457.0  25942   867457.0
# 3   Turkana   926976.0  68233   926976.0
# 4  Marsabit   459785.0  70944   459785.0
# 5     Nyeri   759164.0   3325   759164.0
# 6   Nairobi  4397073.0    704  4397073.0
# 7      Embu        NaN   2821        NaN

# %% [markdown]
# **Specify values as missing values**

# %% [markdown]
# By including na_values= option, you can specify values as missing values.
# In this case, we are telling python to consider dot (.) as missing cases.

# %%
df2 = pd.read_csv("df2.csv", na_values=['.'])
df2["County"]
df2
df2.Population.mean()
df2.columns
#mydata["Area"]
#df2["County"]##Extracting a variable
#df2.County
# Out:
# Index(['County', 'Population', 'Area', 'count'], dtype='object')

# %% [markdown]
# **Changing a column to be index while importing**

# %% [markdown]
# The data has been imported as shown above. We could add the index by specifying the column we want to use. To do this
# we use the index_col parameter followed by the column we want. I.e;
#
# index_col = 'column name'
#
# index_col = value

# %%
df11=pd.read_csv(("df2.csv"),index_col="County")
#df11["count"]
df11
df11.County
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10656\538111063.py in ?()
#       1 df11=pd.read_csv(("df2.csv"),index_col="County")
#       2 #df11["count"]
#       3 df11
# ----> 4 df11.County
#
# ~\dist\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'County'

# %%
df2.Population
# Out:
# 0    4397073.0
# 1    1155574.0
# 2    1208333.0
# 3    1670570.0
# 4     867457.0
# 5     926976.0
# 6     459785.0
# 7     759164.0
# 8    4397073.0
# 9          NaN
# Name: Population, dtype: float64

# %%
import pandas as pd
df2=pd.read_csv(("df.csv"),index_col=0)
df2
# Out:
#           Population   Area      count
# County
# Nairobi    4397073.0    704  4397073.0
# Kisumu     1155574.0   2085  1155574.0
# Mombasa    1208333.0    220  1208333.0
# Bungoma    1670570.0   3024  1670570.0
# Mandera     867457.0  25942   867457.0
# Turkana     926976.0  68233   926976.0
# Marsabit    459785.0  70944   459785.0
# Nyeri       759164.0   3325   759164.0
# Nairobi    4397073.0    704  4397073.0
# Embu             NaN   2821        NaN

# %%
df2.index
# Out:
# Index(['Nairobi', 'Kisumu', 'Mombasa', 'Bungoma', 'Mandera', 'Turkana',
#        'Marsabit', 'Nyeri', 'Nairobi', 'Embu'],
#       dtype='object', name='County')

# %%
df2.columns
# Out:
# Index(['Population', 'Area', 'count'], dtype='object')

# %%
#gives type of data in each column
df2.dtypes
# Out:
# Population    float64
# Area            int64
# count         float64
# dtype: object

# %%
#gives number of entries in each column
df2.count
# Out:
# <bound method DataFrame.count of           Population   Area      count
# County
# Nairobi    4397073.0    704  4397073.0
# Kisumu     1155574.0   2085  1155574.0
# Mombasa    1208333.0    220  1208333.0
# Bungoma    1670570.0   3024  1670570.0
# Mandera     867457.0  25942   867457.0
# Turkana     926976.0  68233   926976.0
# Marsabit    459785.0  70944   459785.0
# Nyeri       759164.0   3325   759164.0
# Nairobi    4397073.0    704  4397073.0
# Embu             NaN   2821        NaN>

# %% [markdown]
# ## After reading the data ,we will go through some operations to check the data, this will enable us to see how our data looks.

# %%
#to get first five observations by default if no value is passed

df=pd.read_csv("df2.csv")
df
# Out:
#      County Population   Area    count
# 0   Nairobi    4397073    704  4397073
# 1    Kisumu    1155574   2085  1155574
# 2   Mombasa    1208333    220  1208333
# 3   Bungoma    1670570   3024  1670570
# 4   Mandera     867457  25942   867457
# 5   Turkana     926976  68233   926976
# 6  Marsabit     459785  70944   459785
# 7     Nyeri     759164   3325   759164
# 8   Nairobi    4397073    704  4397073
# 9      Embu          .   2821        .

# %%
df2.head(4)##Gives first five rows
# Out:
#     County  Population  Area      count
# 0  Nairobi   4397073.0   704  4397073.0
# 1   Kisumu   1155574.0  2085  1155574.0
# 2  Mombasa   1208333.0   220  1208333.0
# 3  Bungoma   1670570.0  3024  1670570.0

# %% [markdown]
# Here we are checking the first five rows in our data. Suppose we wished for the first 3, we
# simply put 3 as an argument in the function. This checks the first 3. By
# default, it checks the first five if no argument is passed

# %%
df.head(3) # This checks the first 3. By default, it checks the first five if no argument is passed
# Out:
#     County Population  Area    count
# 0  Nairobi    4397073   704  4397073
# 1   Kisumu    1155574  2085  1155574
# 2  Mombasa    1208333   220  1208333

# %%
#to get the last five rows in the data by default if no value is passed
df.tail()
# Out:
#      County Population   Area    count
# 5   Turkana     926976  68233   926976
# 6  Marsabit     459785  70944   459785
# 7     Nyeri     759164   3325   759164
# 8   Nairobi    4397073    704  4397073
# 9      Embu          .   2821        .

# %% [markdown]
# This is the vice-versa of the .head() method. Here we are checking the last five rows in our
# data. Suppose we wished for the first 2, we simply put 2 as an argument in the function. if no argument is passed

# %%
df.tail(2) #This checks the last 2. By default, it checks the last five
# Out:
#     County Population  Area    count
# 8  Nairobi    4397073   704  4397073
# 9     Embu          .  2821        .

# %%
df.sample()  #checks a random single row in your data if no argument is passed
# Out:
#     County Population  Area    count
# 0  Nairobi    4397073   704  4397073

# %%
#we can pass arguments
df.sample() # And if suppose we pass in 5 (data.sample(5)) , this checks a sample of 5 rows randomly selected.
# Out:
#     County Population  Area    count
# 0  Nairobi    4397073   704  4397073

# %%
#to get data dimensions 
df.shape
# Out:
# (10, 4)

# %%
df.County.unique()
# Out:
# array(['Nairobi', 'Kisumu', 'Mombasa', 'Bungoma', 'Mandera', 'Turkana',
#        'Marsabit', 'Nyeri', 'Embu'], dtype=object)

# %%
df.County.nunique()
# Out:
# 9

# %% [markdown]
# ### We have two types of data
#
# 1. **Categorical or qualitative**
#                    a)nominal(no order e.g gender)
#                    b) ordinal(has order(e.g education))
#
# 1. **Numerical or quantitative**
#                    a)discrete(specific values e.g houses, cars)
#                    b)continuous(interval e.g range, age, height, weight)

# %% [markdown]
# After inspection of the data, we now want to get an overview of how the data looks like

# %% [markdown]
# ## **Indexing,selection and assigning**

# %% [markdown]
# Indexing in python is done in 2 ways.
#
# 1)By names
#
# 2)By index

# %% [markdown]
# **INDEXING BY NAMES**
#
# - We use `data.loc`, the loc() function helps us to retrieve data values from a dataset at an ease.
# - Using the `loc()` function, we can access the data values fitted in the particular row or column based on the index value passed to the function.
#
# - `.loc` indexing is exclusively ,meaning indexing from 0-10 will select 0-10 inclusively(none will be left out).
#
# **SYNTAX:**
#
# `pandas.DataFrame.loc[index label]`
#
# The index label may be;Single label – example: String, List of string, Slice objects with labels, List of an array of labels, etc.

# %%
import pandas as pd
df2=pd.read_csv("df2.csv")
df3=df2 #not copying the dataset
df3=df2.copy()
#df2.set_index("County",inplace=True)
df2
# Out:
#      County Population   Area    count
# 0   Nairobi    4397073    704  4397073
# 1    Kisumu    1155574   2085  1155574
# 2   Mombasa    1208333    220  1208333
# 3   Bungoma    1670570   3024  1670570
# 4   Mandera     867457  25942   867457
# 5   Turkana     926976  68233   926976
# 6  Marsabit     459785  70944   459785
# 7     Nyeri     759164   3325   759164
# 8   Nairobi    4397073    704  4397073
# 9      Embu          .   2821        .

# %%
df2.loc[0:3, ["Area","count"]] ##indexing
# Out:
#    Area    count
# 0   704  4397073
# 1  2085  1155574
# 2   220  1208333
# 3  3024  1670570

# %%
df3.loc[:, "County":"Area"]
# Out:
#      County Population   Area
# 0   Nairobi    4397073    704
# 1    Kisumu    1155574   2085
# 2   Mombasa    1208333    220
# 3   Bungoma    1670570   3024
# 4   Mandera     867457  25942
# 5   Turkana     926976  68233
# 6  Marsabit     459785  70944
# 7     Nyeri     759164   3325
# 8   Nairobi    4397073    704
# 9      Embu          .   2821

# %%
sliced_df = df3[1:5]["Area"]
sliced_df
# Out:
# 1     2085
# 2      220
# 3     3024
# 4    25942
# Name: Area, dtype: int64

# %%
df2.Area.iloc[1:5] ##indexing
# Out:
# County
# Kisumu      2085
# Mombasa      220
# Bungoma     3024
# Mandera    25942
# Name: Area, dtype: int64

# %% [markdown]
# **Extract One Row from a Data frame**
#
# Set County as the index col `"index_col=County"` when importing or use
# `df2.set_index("County", inplace=True)`

# %% [markdown]
# Now that the index has been set to name, we can access rows of the data
# frame by name using the `loc[]` method of df2:

# %%
df2.set_index("County", inplace=True)
df2
# Out:
#          Population   Area    count
# County
# Nairobi     4397073    704  4397073
# Kisumu      1155574   2085  1155574
# Mombasa     1208333    220  1208333
# Bungoma     1670570   3024  1670570
# Mandera      867457  25942   867457
# Turkana      926976  68233   926976
# Marsabit     459785  70944   459785
# Nyeri        759164   3325   759164
# Nairobi     4397073    704  4397073
# Embu              .   2821        .

# %%
df2
# Out:
#          Population   Area    count
# County
# Nairobi     4397073    704  4397073
# Kisumu      1155574   2085  1155574
# Mombasa     1208333    220  1208333
# Bungoma     1670570   3024  1670570
# Mandera      867457  25942   867457
# Turkana      926976  68233   926976
# Marsabit     459785  70944   459785
# Nyeri        759164   3325   759164
# Nairobi     4397073    704  4397073
# Embu              .   2821        .

# %%
df2.loc["Nairobi"]  #Extracting row one (you need to make County the index)
# Out:
#          Population  Area      count
# County
# Nairobi   4397073.0   704  4397073.0
# Nairobi   4397073.0   704  4397073.0

# %% [markdown]
# **Extract Multiple Rows from a Data frame**

# %%
print(df2.loc[["Bungoma","Embu", "Nyeri"]])
# Out:
#         Population  Area    count
# County
# Bungoma    1670570  3024  1670570
# Embu             .  2821        .
# Nyeri       759164  3325   759164

# %% [markdown]
# **Extract Range of Rows using Python loc()**

# %%
print(df2.loc["Mombasa":"Marsabit"])
# Out:
#          Population   Area    count
# County
# Mombasa     1208333    220  1208333
# Bungoma     1670570   3024  1670570
# Mandera      867457  25942   867457
# Turkana      926976  68233   926976
# Marsabit     459785  70944   459785

# %%
df2.loc["Mandera","Area"]
# Out:
# 25942

# %%
#row 1 column 1(Datum)
df2.loc["Nairobi","Population"] #gives two output since Nairobi is repeated
# Out:
# County
# Nairobi    4397073
# Nairobi    4397073
# Name: Population, dtype: object

# %%
#indexing a range of values in rows and columns
df2.loc["Turkana":"Embu",["Population","count"]]
# Out:
#          Population    count
# County
# Turkana      926976   926976
# Marsabit     459785   459785
# Nyeri        759164   759164
# Nairobi     4397073  4397073
# Embu              .        .

# %%
df3.loc[ 0:5, ["Area", "count"]]
# Out:
#     Area      count
# 0    704  4397073.0
# 1   2085  1155574.0
# 2    220  1208333.0
# 3   3024  1670570.0
# 4  25942   867457.0
# 5  68233   926976.0

# %%
#extract an entire row
df2.loc[:,["Population"]]
# Out:
#          Population
# County
# Nairobi     4397073
# Kisumu      1155574
# Mombasa     1208333
# Bungoma     1670570
# Mandera      867457
# Turkana      926976
# Marsabit        NaN
# Nyeri        759164
# Nairobi     4397073
# Embu              .

# %% [markdown]
# ###  using "get_loc" and "index" methods

# %%
df2.columns.get_loc("count")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df2.columns.get_loc("count")
#
# NameError: name 'df2' is not defined

# %%
df2
# Out:
#          Population   Area    count
# County
# Nairobi     4397073    704  4397073
# Kisumu      1155574   2085  1155574
# Mombasa     1208333    220  1208333
# Bungoma     1670570   3024  1670570
# Mandera      867457  25942   867457
# Turkana      926976  68233   926976
# Marsabit     459785  70944   459785
# Nyeri        759164   3325   759164
# Nairobi     4397073    704  4397073
# Embu              .   2821        .

# %%
start=df2.index[1]
end=df2.index[6]
start,end
# Out:
# ('Kisumu', 'Marsabit')

# %%
df2.loc[start:end,["Population", "Area"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df2.loc[start:end,["Population", "Area"]]
#
# NameError: name 'df2' is not defined

# %% [markdown]
# **Indexing by index**

# %% [markdown]
# **We use data.iloc**
#
# <i/> .iloc uses standard python indexing i.e indexing from 0-10 will select from 0-9

# %%
df3
# Out:
#      County Population   Area    count
# 0   Nairobi    4397073    704  4397073
# 1    Kisumu    1155574   2085  1155574
# 2   Mombasa    1208333    220  1208333
# 3   Bungoma    1670570   3024  1670570
# 4   Mandera     867457  25942   867457
# 5   Turkana     926976  68233   926976
# 6  Marsabit     459785  70944   459785
# 7     Nyeri     759164   3325   759164
# 8   Nairobi    4397073    704  4397073
# 9      Embu          .   2821        .

# %%
df3.iloc[:,0:2:1]
# Out:
#      County Population
# 0   Nairobi    4397073
# 1    Kisumu    1155574
# 2   Mombasa    1208333
# 3   Bungoma    1670570
# 4   Mandera     867457
# 5   Turkana     926976
# 6  Marsabit     459785
# 7     Nyeri     759164
# 8   Nairobi    4397073
# 9      Embu          .

# %%
df3.iloc[5:,0::3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df3.iloc[5:,0::3]
#
# NameError: name 'df3' is not defined

# %%
df3.iloc[0:7,0::2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df3.iloc[0:7,0::2]
#
# NameError: name 'df3' is not defined

# %%
#range of rows and columns
df2.iloc[2:7,0:3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 #range of rows and columns
# ----> 2 df2.iloc[2:7,0:3]
#
# NameError: name 'df2' is not defined

# %%
start=df3.columns.get_loc("Population")
end=df3.columns.get_loc("count")
start,end  
df3.iloc[:, start:end]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 start=df3.columns.get_loc("Population")
#       2 end=df3.columns.get_loc("count")
#       3 start,end
#
# NameError: name 'df3' is not defined

# %%
df3.iloc[[2,5,7]]  #selecting rows with different index position
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df3.iloc[[2,5,7]]
#
# NameError: name 'df3' is not defined

# %%
rows=[2,5,7]
df2.iloc[rows] #I pass a list of values to the .iloc indexer to reproduce the above DataFrame.
# Out:
#         Population   Area    count
# County
# Mombasa    1208333    220  1208333
# Turkana     926976  68233   926976
# Nyeri       759164   3325   759164

# %%
#a value
df3.iloc[1,1]
# Out:
# '1155574'

# %%
df3.iloc[0,2]
# Out:
# 704

# %%
df2.iloc[:,[2]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df2.iloc[:,[2]]
#
# NameError: name 'df2' is not defined

# %% [markdown]
# **Different ways to select columns**
#
# Selecting a single column

# %% [markdown]
# To select the first column 'Population', you can pass the column name as a string to the indexing operator.

# %%
df2[["Population","Area"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df2[["Population","Area"]]
#
# NameError: name 'df2' is not defined

# %% [markdown]
# **You can perform the same task using the dot operator.**

# %%
df2.Population
# Out:
# County
# Nairobi     4397073
# Kisumu      1155574
# Mombasa     1208333
# Bungoma     1670570
# Mandera      867457
# Turkana      926976
# Marsabit     459785
# Nyeri        759164
# Nairobi     4397073
# Embu              .
# Name: Population, dtype: object

# %% [markdown]
# **Selecting multiple columns**

# %% [markdown]
# To select multiple columns, you can pass a list of column names to the indexing operator.

# %%
import pandas as pd
df2=pd.read_csv("df2.csv")

# %%
df2[["Area", "count"]]
# Out:
#     Area      count
# 0    704  4397073.0
# 1   2085  1155574.0
# 2    220  1208333.0
# 3   3024  1670570.0
# 4  25942   867457.0
# 5  68233   926976.0
# 6  70944   459785.0
# 7   3325   759164.0
# 8    704  4397073.0
# 9   2821        NaN

# %%
#selecting multiple columns
df2[["count","Population", "Area"]]
# Out:
#        count  Population   Area
# 0  4397073.0   4397073.0    704
# 1  1155574.0   1155574.0   2085
# 2  1208333.0   1208333.0    220
# 3  1670570.0   1670570.0   3024
# 4   867457.0    867457.0  25942
# 5   926976.0    926976.0  68233
# 6   459785.0    459785.0  70944
# 7   759164.0    759164.0   3325
# 8  4397073.0   4397073.0    704
# 9        NaN         NaN   2821

# %% [markdown]
# Alternatively, you can assign all your columns to a list variable and pass that variable to the indexing operator.

# %%
columns=["count3","population", "area"]
selected_columns=df2[columns]
print(selected_columns)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[95], line 2
#       1 columns=["count3","population", "area"]
# ----> 2 selected_columns=df2[columns]
#       3 print(selected_columns)
#
# File ~\dist\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\dist\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\dist\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['count3', 'population', 'area'], dtype='object')] are in the [columns]"

# %% [markdown]
# **Selecting columns using "select_dtypes" and "filter" methods**
#
# First, check the kind of data stored in each column

# %%
df2.dtypes.value_counts()
# Out:
# object    2
# int64     1
# Name: count, dtype: int64

# %% [markdown]
# Secting the columns with the float data

# %%
df2.dtypes
# Out:
# Population    object
# Area           int64
# count         object
# dtype: object

# %%
df2.select_dtypes(include=["O","int"])
# Out:
#      County   Area
# 0   Nairobi    704
# 1    Kisumu   2085
# 2   Mombasa    220
# 3   Bungoma   3024
# 4   Mandera  25942
# 5   Turkana  68233
# 6  Marsabit  70944
# 7     Nyeri   3325
# 8   Nairobi    704
# 9      Embu   2821

# %% [markdown]
# You can also use the filter method to select columns based on the column names or index labels

# %%
df2
# Out:
#      County  Population   Area      count
# 0   Nairobi   4397073.0    704  4397073.0
# 1    Kisumu   1155574.0   2085  1155574.0
# 2   Mombasa   1208333.0    220  1208333.0
# 3   Bungoma   1670570.0   3024  1670570.0
# 4   Mandera    867457.0  25942   867457.0
# 5   Turkana    926976.0  68233   926976.0
# 6  Marsabit    459785.0  70944   459785.0
# 7     Nyeri    759164.0   3325   759164.0
# 8   Nairobi   4397073.0    704  4397073.0
# 9      Embu         NaN   2821        NaN

# %%
df2.filter(like="co")
# Out:
#        count
# 0  4397073.0
# 1  1155574.0
# 2  1208333.0
# 3  1670570.0
# 4   867457.0
# 5   926976.0
# 6   459785.0
# 7   759164.0
# 8  4397073.0
# 9        NaN

# %% [markdown]
# - Check how to extract variables based on the first alphabet("c")
# - Check how to extract variables based on the last alphabet

# %% [markdown]
# In example above, the filter method returns columns that contain the exact string 'pu'.
# The like parameter takes a string as an input and returns columns that has the string.

# %% [markdown]
# ### **Methods to rename columns in Pandas**

# %% [markdown]
# **Method I : rename() function**

# %%
import pandas as pd
df=pd.read_csv("df2.csv")

# %%
df
# Out:
#      County  Population   Area      count
# 0   Nairobi   4397073.0    704  4397073.0
# 1    Kisumu   1155574.0   2085  1155574.0
# 2   Mombasa   1208333.0    220  1208333.0
# 3   Bungoma   1670570.0   3024  1670570.0
# 4   Mandera    867457.0  25942   867457.0
# 5   Turkana    926976.0  68233   926976.0
# 6  Marsabit    459785.0  70944   459785.0
# 7     Nyeri    759164.0   3325   759164.0
# 8   Nairobi   4397073.0    704  4397073.0
# 9      Embu         NaN   2821        NaN

# %% [markdown]
# Suppose you want to replace column name population with Population_size and count to count_no. In the code below it will create a new dataframe named df3 having new column names and same values.

# %%
df.columns
# Out:
# Index(['county_4', 'Population_2', 'Area_3', 'Count_3'], dtype='object')

# %%
df.rename(columns={"Population":"Population_size", "count":"count_no"})
# Out:
#    county_4  Population_2  Area_3    Count_3
# 0   Nairobi     4397073.0     704  4397073.0
# 1    Kisumu     1155574.0    2085  1155574.0
# 2   Mombasa     1208333.0     220  1208333.0
# 3   Bungoma     1670570.0    3024  1670570.0
# 4   Mandera      867457.0   25942   867457.0
# 5   Turkana      926976.0   68233   926976.0
# 6  Marsabit      459785.0   70944   459785.0
# 7     Nyeri      759164.0    3325   759164.0
# 8   Nairobi     4397073.0     704  4397073.0
# 9      Embu           NaN    2821        NaN

# %% [markdown]
# If you print df2, the variables will still be named with the original names, to make the changes we include a
# parameter `inplace=True`

# %%
df.rename(columns={"Population":"Population_size", "count":"count_no"},inplace=True)

# %%
df
# Out:
#      County  Population   Area      count
# 0   Nairobi   4397073.0    704  4397073.0
# 1    Kisumu   1155574.0   2085  1155574.0
# 2   Mombasa   1208333.0    220  1208333.0
# 3   Bungoma   1670570.0   3024  1670570.0
# 4   Mandera    867457.0  25942   867457.0
# 5   Turkana    926976.0  68233   926976.0
# 6  Marsabit    459785.0  70944   459785.0
# 7     Nyeri    759164.0   3325   759164.0
# 8   Nairobi   4397073.0    704  4397073.0
# 9      Embu         NaN   2821        NaN

# %% [markdown]
# ### Method II : dataframe.columns = [list]

# %% [markdown]
# You can also assign the list of new column names to df.columns. See the example below. We are renaming Population and count columns here.

# %%
import pandas as pd
df=pd.read_csv("df2.csv")
df
# Out:
#      County  Population   Area      count
# 0   Nairobi   4397073.0    704  4397073.0
# 1    Kisumu   1155574.0   2085  1155574.0
# 2   Mombasa   1208333.0    220  1208333.0
# 3   Bungoma   1670570.0   3024  1670570.0
# 4   Mandera    867457.0  25942   867457.0
# 5   Turkana    926976.0  68233   926976.0
# 6  Marsabit    459785.0  70944   459785.0
# 7     Nyeri    759164.0   3325   759164.0
# 8   Nairobi   4397073.0    704  4397073.0
# 9      Embu         NaN   2821        NaN

# %%
df.columns
# Out:
# Index(['county_4', 'Population_2', 'Area_3', 'Count_3'], dtype='object')

# %%
df.columns=["county_4","Population_2","Area_3","Count_3"]
df
# Out:
#    county_4  Population_2  Area_3    Count_3
# 0   Nairobi     4397073.0     704  4397073.0
# 1    Kisumu     1155574.0    2085  1155574.0
# 2   Mombasa     1208333.0     220  1208333.0
# 3   Bungoma     1670570.0    3024  1670570.0
# 4   Mandera      867457.0   25942   867457.0
# 5   Turkana      926976.0   68233   926976.0
# 6  Marsabit      459785.0   70944   459785.0
# 7     Nyeri      759164.0    3325   759164.0
# 8   Nairobi     4397073.0     704  4397073.0
# 9      Embu           NaN    2821        NaN

# %% [markdown]
# ### Rename columns having pattern

# %% [markdown]
# **Changing the order of your columns**

# %% [markdown]
# Suppose you want to rename columns having underscore '_' in their names. You want to get rid of underscore

# %%
df.columns = df.columns.str.replace('_' , "")
df
# Out:
#     county4  Population2  Area3     Count3
# 0   Nairobi    4397073.0    704  4397073.0
# 1    Kisumu    1155574.0   2085  1155574.0
# 2   Mombasa    1208333.0    220  1208333.0
# 3   Bungoma    1670570.0   3024  1670570.0
# 4   Mandera     867457.0  25942   867457.0
# 5   Turkana     926976.0  68233   926976.0
# 6  Marsabit     459785.0  70944   459785.0
# 7     Nyeri     759164.0   3325   759164.0
# 8   Nairobi    4397073.0    704  4397073.0
# 9      Embu          NaN   2821        NaN

# %% [markdown]
# New column names are as shown above, you can observe no underscore in the column names.

# %%
df.columns
# Out:
# Index(['county4', 'Population2', 'Area3', 'Count3'], dtype='object')

# %%
group1=["county4","Area3"]
group2=["Count3","Population2"]
new_cols=group1+group2
set(df.columns)==set(new_cols)
dft_2=df[new_cols]
print(dft_2)
# Out:
#     county4  Area3     Count3  Population2
# 0   Nairobi    704  4397073.0    4397073.0
# 1    Kisumu   2085  1155574.0    1155574.0
# 2   Mombasa    220  1208333.0    1208333.0
# 3   Bungoma   3024  1670570.0    1670570.0
# 4   Mandera  25942   867457.0     867457.0
# 5   Turkana  68233   926976.0     926976.0
# 6  Marsabit  70944   459785.0     459785.0
# 7     Nyeri   3325   759164.0     759164.0
# 8   Nairobi    704  4397073.0    4397073.0
# 9      Embu   2821        NaN          NaN

# %% [markdown]
# **4)How to get summary statistics of your data**

# %%
dft_2["Area3"].mean()
# Out:
# 17800.2

# %%
dft_2["Population2"].mode()
# Out:
# 0    4397073.0
# Name: Population2, dtype: float64

# %%
dft_2["Area3"].median()
# Out:
# 2922.5

# %%
#max value
dft_2["Area3"].max()
# Out:
# 70944

# %%
#minimum value
df2["Population"].min()
# Out:
# 459785.0

# %%
#gives position of most maximum number
df2["Population"].argmax()
# Out:
# 0

# %%
df2
# Out:
#      County  Population   Area   count
# 0   Nairobi     4397073    704 4397073
# 1    Kisumu     1155574   2085 1155574
# 2   Mombasa     1208333    220 1208333
# 3   Bungoma     1670570   3024 1670570
# 4   Mandera      867457  25942  867457
# 5   Turkana      926976  68233  926976
# 6  Marsabit      459785  70944  459785
# 7     Nyeri      759164   3325  759164
# 8   Nairobi     4397073    704 4397073
# 9      Embu         NaN   2821     NaN

# %%
#gives position of most minimum number
df2["Population"].argmin()
# Out:
# 6

# %%
#summary stats of  population
df2["Area"].describe()
# Out:
# count      10
# mean    17800
# std     28337
# min       220
# 25%      1049
# 50%      2922
# 75%     20288
# max     70944
# Name: Area, dtype: float64

# %%
df2["Area"].unique()
# Out:
# array([  704,  2085,   220,  3024, 25942, 68233, 70944,  3325,  2821],
#       dtype=int64)

# %%
df2["Area"].nunique()
# Out:
# 9

# %%
#gives summary statistics(numeric data)
df2.describe()
# Out:
#        Population  Area   count
# count           9    10       9
# mean      1760223 17800 1760223
# std       1531697 28337 1531697
# min        459785   220  459785
# 25%        867457  1049  867457
# 50%       1155574  2922 1155574
# 75%       1670570 20288 1670570
# max       4397073 70944 4397073

# %%
#gives standard deviation
df2["Population"].std()
# Out:
# 1552244.2546286697

# %% [markdown]
# - To get summary stats of categorical data we include a parameter "O"(uppercase O).

# %%
#summary stats of categorical data
df2.describe(include ="O")
# Out:
#          County
# count        10
# unique        9
# top     Nairobi
# freq          2

# %%
df2["County"].dtype
# Out:
# dtype('O')

# %%
df2
# Out:
#      County  Population   Area   count
# 0   Nairobi     4397073    704 4397073
# 1    Kisumu     1155574   2085 1155574
# 2   Mombasa     1208333    220 1208333
# 3   Bungoma     1670570   3024 1670570
# 4   Mandera      867457  25942  867457
# 5   Turkana      926976  68233  926976
# 6  Marsabit      459785  70944  459785
# 7     Nyeri      759164   3325  759164
# 8   Nairobi     4397073    704 4397073
# 9      Embu         NaN   2821     NaN

# %%
#to check unique/specific levels in a column

df3["County"].unique()
# Out:
# array(['Nairobi', 'Kisumu', 'Mombasa', 'Bungoma', 'Mandera', 'Turkana',
#        'Marsabit', 'Nyeri', 'Embu'], dtype=object)

# %%
#count of unique levels
df3["County"].nunique()
# Out:
# 9

# %%
len(df2["County"].unique())
# Out:
# 9

# %% [markdown]
# **CHECKING FOR MISSING VALUES IN OUR DATA**

# %% [markdown]
# - we use any of the functions below:
#      - `data.isnull() `
#      - `data.isna()`
#
# - It returns a data frame filled with bools,depending on whether the missing values are present in the data or not.

# %%
df=pd.read_csv("df2.csv", na_values=["."])
df
# Out:
#      County  Population   Area      count
# 0   Nairobi   4397073.0    704  4397073.0
# 1    Kisumu   1155574.0   2085  1155574.0
# 2   Mombasa   1208333.0    220  1208333.0
# 3   Bungoma   1670570.0   3024  1670570.0
# 4   Mandera    867457.0  25942   867457.0
# 5   Turkana    926976.0  68233   926976.0
# 6  Marsabit    459785.0  70944   459785.0
# 7     Nyeri    759164.0   3325   759164.0
# 8   Nairobi   4397073.0    704  4397073.0
# 9      Embu         NaN   2821        NaN

# %%
df.isna()
# Out:
#    County  Population   Area  count
# 0   False       False  False  False
# 1   False       False  False  False
# 2   False       False  False  False
# 3   False       False  False  False
# 4   False       False  False  False
# 5   False       False  False  False
# 6   False       False  False  False
# 7   False       False  False  False
# 8   False       False  False  False
# 9   False        True  False   True

# %% [markdown]
#  We need to check at some functions to summarise the missing values statistics when dealing with large dataset
#
# - `data.isnull().all()`--Returns true if all values/observations in a column are null else returns false
#
# - `data.isnull().sum()`--gives sum of missing values in each variable
#
# - `data.isnull().any()`--checks if there exists any null values in individual columns and returns true if they exist and false if they dont

# %%
df.isnull().all()
# Out:
# County        False
# Population    False
# Area          False
# count         False
# dtype: bool

# %%
df.isna().any()
# Out:
# County        False
# Population     True
# Area          False
# count          True
# dtype: bool

# %%
df.isna().sum()
# Out:
# County        0
# Population    2
# Area          0
# count         1
# dtype: int64

# %% [markdown]
# **DEALING WITH MISSING VALUES**

# %% [markdown]
# **a)Dropna**

# %%
df
# Out:
#      County  Population   Area      count
# 0   Nairobi   4397073.0    704  4397073.0
# 1    Kisumu   1155574.0   2085  1155574.0
# 2   Mombasa   1208333.0    220  1208333.0
# 3   Bungoma   1670570.0   3024  1670570.0
# 4   Mandera    867457.0  25942   867457.0
# 5   Turkana    926976.0  68233   926976.0
# 6  Marsabit    459785.0  70944   459785.0
# 7     Nyeri    759164.0   3325   759164.0
# 8   Nairobi   4397073.0    704  4397073.0
# 9      Embu         NaN   2821        NaN

# %%
#drops by default all rows with na
df.dropna(axis="columns", inplace=True)
df
#by default axis='rows'
# Out:
#      County   Area
# 0   Nairobi    704
# 1    Kisumu   2085
# 2   Mombasa    220
# 3   Bungoma   3024
# 4   Mandera  25942
# 5   Turkana  68233
# 6  Marsabit  70944
# 7     Nyeri   3325
# 8   Nairobi    704
# 9      Embu   2821

# %%
#drops all columns with na values
df2.dropna()
#or axis = 1
# Out:
#      County  Population   Area      count
# 0   Nairobi   4397073.0    704  4397073.0
# 1    Kisumu   1155574.0   2085  1155574.0
# 2   Mombasa   1208333.0    220  1208333.0
# 3   Bungoma   1670570.0   3024  1670570.0
# 4   Mandera    867457.0  25942   867457.0
# 5   Turkana    926976.0  68233   926976.0
# 6  Marsabit    459785.0  70944   459785.0
# 7     Nyeri    759164.0   3325   759164.0
# 8   Nairobi   4397073.0    704  4397073.0

# %%
df
# Out:
#      County   Area
# 0   Nairobi    704
# 1    Kisumu   2085
# 2   Mombasa    220
# 3   Bungoma   3024
# 4   Mandera  25942
# 5   Turkana  68233
# 6  Marsabit  70944
# 7     Nyeri   3325
# 8   Nairobi    704
# 9      Embu   2821

# %% [markdown]
# - the best way to deal with nas is to fill them with values
#
# - we use the function fillna

# %%
import pandas as pd
df=pd.read_csv("df2.csv")

# %%
df["Population"]
# Out:
# 0    4397073.0
# 1    1155574.0
# 2    1208333.0
# 3    1670570.0
# 4     867457.0
# 5     926976.0
# 6     459785.0
# 7     759164.0
# 8    4397073.0
# 9          NaN
# Name: Population, dtype: float64

# %%
df.Population.fillna(20,inplace=True)
df
# Out:
#      County  Population   Area      count
# 0   Nairobi   4397073.0    704  4397073.0
# 1    Kisumu   1155574.0   2085  1155574.0
# 2   Mombasa   1208333.0    220  1208333.0
# 3   Bungoma   1670570.0   3024  1670570.0
# 4   Mandera    867457.0  25942   867457.0
# 5   Turkana    926976.0  68233   926976.0
# 6  Marsabit    459785.0  70944   459785.0
# 7     Nyeri    759164.0   3325   759164.0
# 8   Nairobi   4397073.0    704  4397073.0
# 9      Embu        20.0   2821        NaN

# %% [markdown]
# . Check how to deal with the dot(".")
#
# . Write a code which will replace the missing for "Population" and "Count" at the same time.

# %%
df["count"].fillna(df["count"].median(),inplace=True)
#df2=df2.round(1)
df
#pd.reset_option(lambda x:'%.5f' % x, axis=1)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12892\1376651429.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["count"].fillna(df["count"].median(),inplace=True)
#      County  Population   Area      count
# 0   Nairobi   4397073.0    704  4397073.0
# 1    Kisumu   1155574.0   2085  1155574.0
# 2   Mombasa   1208333.0    220  1208333.0
# 3   Bungoma   1670570.0   3024  1670570.0
# 4   Mandera    867457.0  25942   867457.0
# 5   Turkana    926976.0  68233   926976.0
# 6  Marsabit    459785.0  70944   459785.0
# 7     Nyeri    759164.0   3325   759164.0
# 8   Nairobi   4397073.0    704  4397073.0
# 9      Embu        20.0   2821  1155574.0

# %%
#fills na values in population column with mean
x=df["Population"].mean()
df["Population"].fillna(x,inplace= True)
print(df)
x
# Out:
#      County    Population   Area      count
# 0   Nairobi  4.397073e+06    704  4397073.0
# 1    Kisumu  1.155574e+06   2085  1155574.0
# 2   Mombasa  1.208333e+06    220  1208333.0
# 3   Bungoma  1.670570e+06   3024  1670570.0
# 4   Mandera  8.674570e+05  25942   867457.0
# 5   Turkana  9.269760e+05  68233   926976.0
# 6  Marsabit  4.597850e+05  70944   459785.0
# 7     Nyeri  7.591640e+05   3325   759164.0
# 8   Nairobi  4.397073e+06    704  4397073.0
# 9      Embu  1.760223e+06   2821  1155574.0
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12892\1576233526.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Population"].fillna(x,inplace= True)
# 1760222.7777777775

# %%
import pandas as pd
df=pd.read_csv("df2.csv")
df.fillna({"count": df["count"].median(), "Population": df["Population"].mean()}, inplace=True)
pd.options.display.float_format = '{:.0f}'.format
df
# Out:
#      County  Population   Area   count
# 0   Nairobi     4397073    704 4397073
# 1    Kisumu     1155574   2085 1155574
# 2   Mombasa     1208333    220 1208333
# 3   Bungoma     1670570   3024 1670570
# 4   Mandera      867457  25942  867457
# 5   Turkana      926976  68233  926976
# 6  Marsabit      459785  70944  459785
# 7     Nyeri      759164   3325  759164
# 8   Nairobi     4397073    704 4397073
# 9      Embu     1760223   2821 1155574

# %%
import pandas as pd
df=pd.read_csv("df2.csv")
# Fill numeric columns with the median
numeric_cols = df.select_dtypes(include=['number']).columns
df[numeric_cols] = df[numeric_cols].apply(lambda x: x.fillna(x.median()), axis=0)
# Fill categorical columns with the mode
categorical_cols = df.select_dtypes(include=['object', 'category']).columns
df[categorical_cols] = df[categorical_cols].apply(lambda x: x.fillna(x.mode()[0]), axis=0)
df
# Out:
#      County  Population   Area   count
# 0   Nairobi     4397073    704 4397073
# 1    Kisumu     1155574   2085 1155574
# 2   Mombasa     1208333    220 1208333
# 3   Bungoma     1670570   3024 1670570
# 4   Mandera      867457  25942  867457
# 5   Turkana      926976  68233  926976
# 6  Marsabit      459785  70944  459785
# 7     Nyeri      759164   3325  759164
# 8   Nairobi     4397073    704 4397073
# 9      Embu     1155574   2821 1155574

# %%
x = df2["Population"].mode()[0]
x
# Out:
# 4397073.0

# %% [raw]
# Write a code which will replace the variables with the mean/median at the same time.

# %% [markdown]
# - By  default inplace = false.
#
# - inplace = true it means that the changes will be done to the original data
#
# - By default i.e inplace = false you have to assign it to something a new variable or the same variable just to hold the changes.
#
# - If inplace=true the data is modified in place and the original data is updated.
#
# - The **include** parameter is commonly used in the following methods:
#
#    - **dropna()**
#
#    - **drop_duplicates()**
#
#    -**fillna()**
#    - **Query()**

# %% [raw]
# 1. Use the drop duplicate function to drop the first duplicate in df2
# 2.  Use the drop duplicate function to drop the second duplicate in df2
# 3.  Use the drop duplicate function to drop the both duplicate in df2
# 4. Using the query function filter the observations from bungoma with a Population greater than 1m
# 5. Using the query function extract the counties with AREA less than 1000
# 6. Using the query function extract the counties with AREA less than 1000 and Count greater than 1m.

# %% [markdown]
# **check how the following functions work**

# %% [markdown]
# **d. query()**
#
# - used to query the columns of a dataframe with a boolean expression.
# - The `query()` method allows you to query the DataFrame.
#
# - The `query()` method takes a query expression as a string parameter, which has to evaluate to either True of False.
#
# - It returns the DataFrame where the result is True according to the query expression.

# %% [markdown]
# **Syntax**

# %% [raw]
# dataframe.query(expr, inplace)

# %%
import pandas as pd
df2=pd.read_csv(("df2.csv"))
df2
# Out:
#      County Population   Area      count
# 0   Nairobi    4397073    704  4397073.0
# 1    Kisumu    1155574   2085  1155574.0
# 2   Mombasa    1208333    220  1208333.0
# 3   Bungoma    1670570   3024  1670570.0
# 4   Mandera     867457  25942   867457.0
# 5   Turkana     926976  68233   926976.0
# 6  Marsabit        NaN  70944   459785.0
# 7     Nyeri     759164   3325   759164.0
# 8   Nairobi    4397073    704  4397073.0
# 9      Embu          .   2821        NaN

# %%
df2.query('Area != 25942').reset_index(drop=True)
# Out:
#     county2  Population   Area     Count3
# 0   Nairobi   4397073.0    704  4397073.0
# 1    Kisumu   1155574.0   2085  1155574.0
# 2   Mombasa   1208333.0    220  1208333.0
# 3   Bungoma   1670570.0   3024  1670570.0
# 4   Turkana    926976.0  68233   926976.0
# 5  Marsabit    459785.0  70944   459785.0
# 6     Nyeri    759164.0   3325   759164.0
# 7   Nairobi   4397073.0    704  4397073.0
# 8      Embu     20000.0   2821  1760222.8

# %%
df2.query('Area>700 or Count3==926976')
# Out:
#     county2  Population   Area     Count3
# 0   Nairobi   4397073.0    704  4397073.0
# 1    Kisumu   1155574.0   2085  1155574.0
# 3   Bungoma   1670570.0   3024  1670570.0
# 4   Mandera    867457.0  25942   867457.0
# 5   Turkana    926976.0  68233   926976.0
# 6  Marsabit    459785.0  70944   459785.0
# 7     Nyeri    759164.0   3325   759164.0
# 8   Nairobi   4397073.0    704  4397073.0
# 9      Embu     20000.0   2821  1760222.8

# %% [markdown]
# **e)rename()**
#
#  It renames any index,column or row.

# %%
#example
df2.rename(index={0:"a",1:"b"},inplace =True)
df2.rename(columns={"County":"a","Population":"b","Area":"c","count":"d"},inplace=True)

# %%
df2
# Out:
#      County  Population   Area      count
# 0   Nairobi   4397073.0    704  4397073.0
# 1    Kisumu   1155574.0   2085  1155574.0
# 2   Mombasa   1208333.0    220  1208333.0
# 3   Bungoma   1670570.0   3024  1670570.0
# 4   Mandera    867457.0  25942   867457.0
# 5   Turkana    926976.0  68233   926976.0
# 6  Marsabit        20.0  70944   459785.0
# 7     Nyeri    759164.0   3325   759164.0
# 8   Nairobi   4397073.0    704  4397073.0
# 9      Embu        20.0   2821  1155574.0

# %% [markdown]
# **f)reset_index()**

# %%
df=pd.read_csv("df.csv")
df3=df.dropna()
df3
# Out:
#     County  Population   Area      count
# 0  Nairobi   4397073.0    704  4397073.0
# 1   Kisumu   1155574.0   2085  1155574.0
# 2  Mombasa   1208333.0    220  1208333.0
# 3  Bungoma   1670570.0   3024  1670570.0
# 4  Mandera    867457.0  25942   867457.0
# 5  Turkana    926976.0  68233   926976.0
# 7    Nyeri    759164.0   3325   759164.0
# 8  Nairobi   4397073.0    704  4397073.0

# %% [markdown]
# resets the index of  a data frame and uses the default one instead

# %%
#makes the existing index as a column and uses default indexing
df3.reset_index(drop=True)
# Out:
#     County  Population   Area      count
# 0  Nairobi   4397073.0    704  4397073.0
# 1   Kisumu   1155574.0   2085  1155574.0
# 2  Mombasa   1208333.0    220  1208333.0
# 3  Bungoma   1670570.0   3024  1670570.0
# 4  Mandera    867457.0  25942   867457.0
# 5  Turkana    926976.0  68233   926976.0
# 6    Nyeri    759164.0   3325   759164.0
# 7  Nairobi   4397073.0    704  4397073.0

# %%
#drops the existing index and uses the default one
df2=df2.reset_index(drop = True)
df2
# Out:
#           a          b      c          d
# 0   Nairobi  4397073.0    704  4397073.0
# 1    Kisumu  1155574.0   2085  1155574.0
# 2   Mombasa  1208333.0    220  1208333.0
# 3   Bungoma  1670570.0   3024  1670570.0
# 4   Mandera   867457.0  25942   867457.0
# 5   Turkana   926976.0  68233   926976.0
# 6  Marsabit        NaN  70944   459785.0
# 7     Nyeri   759164.0   3325   759164.0
# 8   Nairobi  4397073.0    704  4397073.0
# 9      Embu        NaN   2821        NaN

# %% [markdown]
# **g)sort_index()**

# %% [markdown]
# --returns a new data frame sorted by label if inplace argument is false.
#
# --otherwise updates the original dataframe and returns none

# %%
df3=df3.sort_index()
df3
# Out:
#     County  Population   Area      count
# 0  Nairobi   4397073.0    704  4397073.0
# 1   Kisumu   1155574.0   2085  1155574.0
# 2  Mombasa   1208333.0    220  1208333.0
# 3  Bungoma   1670570.0   3024  1670570.0
# 4  Mandera    867457.0  25942   867457.0
# 5  Turkana    926976.0  68233   926976.0
# 7    Nyeri    759164.0   3325   759164.0
# 8  Nairobi   4397073.0    704  4397073.0

# %%
df3
# Out:
#     County  Population   Area      count
# 0  Nairobi   4397073.0    704  4397073.0
# 1   Kisumu   1155574.0   2085  1155574.0
# 2  Mombasa   1208333.0    220  1208333.0
# 3  Bungoma   1670570.0   3024  1670570.0
# 4  Mandera    867457.0  25942   867457.0
# 5  Turkana    926976.0  68233   926976.0
# 7    Nyeri    759164.0   3325   759164.0
# 8  Nairobi   4397073.0    704  4397073.0

# %%
df2.sort_index(ascending = False)
# Out:
#           a          b      c          d
# 9      Embu        NaN   2821        NaN
# 8   Nairobi  4397073.0    704  4397073.0
# 7     Nyeri   759164.0   3325   759164.0
# 6  Marsabit        NaN  70944   459785.0
# 5   Turkana   926976.0  68233   926976.0
# 4   Mandera   867457.0  25942   867457.0
# 3   Bungoma  1670570.0   3024  1670570.0
# 2   Mombasa  1208333.0    220  1208333.0
# 1    Kisumu  1155574.0   2085  1155574.0
# 0   Nairobi  4397073.0    704  4397073.0

# %% [markdown]
# **h)sort_value()**
#
# --sort by the values along either axis

# %%
df3.sort_values(by=["County"])
# Out:
#     County  Population   Area      count
# 3  Bungoma   1670570.0   3024  1670570.0
# 1   Kisumu   1155574.0   2085  1155574.0
# 4  Mandera    867457.0  25942   867457.0
# 2  Mombasa   1208333.0    220  1208333.0
# 0  Nairobi   4397073.0    704  4397073.0
# 8  Nairobi   4397073.0    704  4397073.0
# 7    Nyeri    759164.0   3325   759164.0
# 5  Turkana    926976.0  68233   926976.0

# %%
df3.drop('Area',axis=1,inplace=True)
df3
# Out:
#     County  Population      count
# 0  Nairobi   4397073.0  4397073.0
# 1   Kisumu   1155574.0  1155574.0
# 2  Mombasa   1208333.0  1208333.0
# 3  Bungoma   1670570.0  1670570.0
# 4  Mandera    867457.0   867457.0
# 5  Turkana    926976.0   926976.0
# 7    Nyeri    759164.0   759164.0
# 8  Nairobi   4397073.0  4397073.0

# %%
#fills all nas in the data with the given value
df2.fillna(1463451,inplace = True)

# %%
df3['e']=[1,2,3,4,5,6,7,8]
df3
# Out:
#     County  Population      count  e
# 0  Nairobi   4397073.0  4397073.0  1
# 1   Kisumu   1155574.0  1155574.0  2
# 2  Mombasa   1208333.0  1208333.0  3
# 3  Bungoma   1670570.0  1670570.0  4
# 4  Mandera    867457.0   867457.0  5
# 5  Turkana    926976.0   926976.0  6
# 7    Nyeri    759164.0   759164.0  7
# 8  Nairobi   4397073.0  4397073.0  8

# %%
df2.query('c==704')
# Out:
#            b    c          d
# 0  4397073.0  704  4397073.0
# 8  4397073.0  704  4397073.0

# %%
#add new column
df2['e']=5

# %%
#a column with specific values
df2['e']=[1,2,3,4,5,6,7,8,9]

# %%
df2.dtypes
# Out:
# County         object
# Population      int32
# Area            int64
# count         float64
# dtype: object

# %% [markdown]
# - We need to convert the population variable to float or integer.

# %%
#df2.fillna(200, inplace=True)
df2.dtypes
# Out:
# County         object
# Population    float64
# Area          float64
# count         float64
# dtype: object

# %%
df2["Area"]=df2["Area"].astype(np.float64)

# %%
df2['density']=df2['Population'] / df2['Area']
df2
# Out:
#      County  Population     Area      count      density
# 0   Nairobi   4397073.0    704.0  4397073.0  6245.842330
# 1    Kisumu   1155574.0   2085.0  1155574.0   554.232134
# 2   Mombasa   1208333.0    220.0  1208333.0  5492.422727
# 3   Bungoma   1670570.0   3024.0  1670570.0   552.437169
# 4   Mandera    867457.0  25942.0   867457.0    33.438324
# 5   Turkana    926976.0  68233.0   926976.0    13.585450
# 6  Marsabit        20.0  70944.0   459785.0     0.000282
# 7     Nyeri    759164.0   3325.0   759164.0   228.320000
# 8   Nairobi   4397073.0    704.0  4397073.0  6245.842330
# 9      Embu        20.0   2821.0  1155574.0     0.007090

# %% [markdown]
# **Boolean indexing**  (filtering)

# %% [markdown]
# --Uses single column values to select data.

# %%
df[df.Area>200].reset_index(drop=True)
# Out:
#      County  Population   Area      count
# 0   Nairobi   4397073.0    704  4397073.0
# 1    Kisumu   1155574.0   2085  1155574.0
# 2   Mombasa   1208333.0    220  1208333.0
# 3   Bungoma   1670570.0   3024  1670570.0
# 4   Mandera    867457.0  25942   867457.0
# 5   Turkana    926976.0  68233   926976.0
# 6  Marsabit   1922777.5  70944   459785.0
# 7     Nyeri    759164.0   3325   759164.0
# 8   Nairobi   4397073.0    704  4397073.0
# 9      Embu   1922777.5   2821        NaN

# %%
df2[df2["count"]>867457]
# Out:
#     County  Population   Area      count
# 0  Nairobi   4397073.0    704  4397073.0
# 1   Kisumu   1155574.0   2085  1155574.0
# 2  Mombasa   1208333.0    220  1208333.0
# 3  Bungoma   1670570.0   3024  1670570.0
# 5  Turkana    926976.0  68233   926976.0
# 8  Nairobi   4397073.0    704  4397073.0

# %%
df.drop("Area",axis= 1, inplace=True)

# %%
df
# Out:
#      County  Population      count
# 0   Nairobi   4397073.0  4397073.0
# 1    Kisumu   1155574.0  1155574.0
# 2   Mombasa   1208333.0  1208333.0
# 3   Bungoma   1670570.0  1670570.0
# 4   Mandera    867457.0   867457.0
# 5   Turkana    926976.0   926976.0
# 6  Marsabit   1922777.5   459785.0
# 7     Nyeri    759164.0   759164.0
# 8   Nairobi   4397073.0  4397073.0
# 9      Embu   1922777.5        NaN

# %%
del(df["Population"])

# %%
df
# Out:
#      County      count
# 0   Nairobi  4397073.0
# 1    Kisumu  1155574.0
# 2   Mombasa  1208333.0
# 3   Bungoma  1670570.0
# 4   Mandera   867457.0
# 5   Turkana   926976.0
# 6  Marsabit   459785.0
# 7     Nyeri   759164.0
# 8   Nairobi  4397073.0
# 9      Embu        NaN

# %% [markdown]
# **dropping columns**

# %% [raw]
# df2.drop('a',axis=1,inplace = True)

# %%
del(df2['b'])

# %%
df2
# Out:
#      County  Population      count
# 0   Nairobi     4397073  4397073.0
# 1    Kisumu     1155574  1155574.0
# 2   Mombasa     1208333  1208333.0
# 3   Bungoma     1670570  1670570.0
# 4   Mandera      867457   867457.0
# 5   Turkana      926976   926976.0
# 6  Marsabit         200   459785.0
# 7     Nyeri      759164   759164.0
# 8   Nairobi     4397073  4397073.0
# 9      Embu         200      200.0

# %%
df2.drop("Area",axis=1,inplace=True)

# %%
del [df2["density"]]

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      ------------------------------------ 250.0/250.0 kB 426.6 kB/s eta 0:00:00
# Collecting et-xmlfile
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
ph1=pd.read_excel("census population households.xlsx",thousands=",")
ph1
# Out:
#       County Sub County  Population  Households  Average Household Size
# 0    Mombasa  Changamwe    130541.0     46614.0                     2.8
# 1    Mombasa      Jomvu    162760.0     53472.0                     3.0
# 2    Mombasa    Kisauni    287131.0     88202.0                     3.3
# 3    Mombasa     Likoni    249230.0     81191.0                     3.1
# 4    Mombasa      Mvita    147983.0     38995.0                     3.8
# ..       ...        ...         ...         ...                     ...
# 343  Nairobi   Makadara    188792.0     70361.0                     2.7
# 344  Nairobi    Mathare    204469.0     74967.0                     2.7
# 345  Nairobi      Njiru    623471.0    204563.0                     3.0
# 346  Nairobi    Starehe    194726.0     69389.0                     2.8
# 347  Nairobi  Westlands    301295.0    104980.0                     2.9
#
# [348 rows x 5 columns]

# %%
ph1.dtypes
# Out:
# County                     object
# Sub County                 object
# Population                float64
# Households                float64
# Average Household Size    float64
# dtype: object

# %%
df2["Population"]=df2["Population"].astype(np.int32) ###Changing the data Population to integer
# Out:
# 136850.09275362318

# %%
df2=pd.read_csv("df2.csv")
df2
# Out:
#      County Population   Area      count
# 0   Nairobi    4397073    704  4397073.0
# 1    Kisumu    1155574   2085  1155574.0
# 2   Mombasa    1208333    220  1208333.0
# 3   Bungoma    1670570   3024  1670570.0
# 4   Mandera     867457  25942   867457.0
# 5   Turkana     926976  68233   926976.0
# 6  Marsabit        NaN  70944   459785.0
# 7     Nyeri     759164   3325   759164.0
# 8   Nairobi    4397073    704  4397073.0
# 9      Embu          .   2821        NaN

# %%
#this is not a copy
df=df2.copy()
df
# Out:
#      County  Population      count
# 0   Nairobi     4397073  4397073.0
# 1    Kisumu     1155574  1155574.0
# 2   Mombasa     1208333  1208333.0
# 3   Bungoma     1670570  1670570.0
# 4   Mandera      867457   867457.0
# 5   Turkana      926976   926976.0
# 6  Marsabit         200   459785.0
# 7     Nyeri      759164   759164.0
# 8   Nairobi     4397073  4397073.0
# 9      Embu         200      200.0

# %%
#this is a copy any changes made on df are not reflected on df2 and vice versa
df=df2.copy()

# %% [raw]
# pd.merge[data1,data2, on="column name"] ##syntax

# %%
pd.merge(ph1,cad, on="Sub County")
# Out:
#       County Sub County  Population  Households  Average Household Size  \
# 0    Mombasa  Changamwe    130541.0     46614.0                     2.8
# 1    Mombasa      Jomvu    162760.0     53472.0                     3.0
# 2    Mombasa    Kisauni    287131.0     88202.0                     3.3
# 3    Mombasa     Likoni    249230.0     81191.0                     3.1
# 4    Mombasa      Mvita    147983.0     38995.0                     3.8
# ..       ...        ...         ...         ...                     ...
# 371  Nairobi   Makadara    188792.0     70361.0                     2.7
# 372  Nairobi    Mathare    204469.0     74967.0                     2.7
# 373  Nairobi      Njiru    623471.0    204563.0                     3.0
# 374  Nairobi    Starehe    194726.0     69389.0                     2.8
# 375  Nairobi  Westlands    301295.0    104980.0                     2.9
#
#       Area Density
# 0     17.7   7,457
# 1     36.9   4,432
# 2     87.7   3,328
# 3     40.5   6,187
# 4     14.6  10,543
# ..     ...     ...
# 371   11.7  16,150
# 372      3  68,941
# 373  129.9   4,821
# 374   20.6  10,205
# 375   97.5   3,167
#
# [376 rows x 7 columns]

# %% [markdown]
# **5)merging datasets**
#
# - when merging datasets it is important to merge the datasets on the column that exist in both data sets and it has unique values.
#
# - this helps in avoiding to redo the cleaning again in a merged dataset.
#
# - we use the following syntax to merge.

# %% [markdown]
# - Concatenate function
# - Append function

# %%
df2=pd.read_csv("df2.csv")
df=df2.copy()
pd.merge(df2,df,on="count")
# Out:
#     County_x  Population_x  Area_x      count  County_y  Population_y  Area_y
# 0    Nairobi     4397073.0     704  4397073.0   Nairobi     4397073.0     704
# 1    Nairobi     4397073.0     704  4397073.0   Nairobi     4397073.0     704
# 2    Nairobi     4397073.0     704  4397073.0   Nairobi     4397073.0     704
# 3    Nairobi     4397073.0     704  4397073.0   Nairobi     4397073.0     704
# 4     Kisumu     1155574.0    2085  1155574.0    Kisumu     1155574.0    2085
# 5    Mombasa     1208333.0     220  1208333.0   Mombasa     1208333.0     220
# 6    Bungoma     1670570.0    3024  1670570.0   Bungoma     1670570.0    3024
# 7    Mandera      867457.0   25942   867457.0   Mandera      867457.0   25942
# 8    Turkana      926976.0   68233   926976.0   Turkana      926976.0   68233
# 9   Marsabit           NaN   70944   459785.0  Marsabit           NaN   70944
# 10     Nyeri      759164.0    3325   759164.0     Nyeri      759164.0    3325
# 11      Embu           NaN    2821        NaN      Embu           NaN    2821

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   County      10 non-null     object
#  1   Population  8 non-null      float64
#  2   Area        10 non-null     int64
#  3   count       9 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 448.0+ bytes

# %%
df2["Population"]=df2["Population"].astype(np.int32) ###Changing the data Population to integer

# %%
df2
# Out:
#     County  Population   Area      count
# 0  Nairobi     4397073    704  4397073.0
# 1   Kisumu     1155574   2085  1155574.0
# 2  Mombasa     1208333    220  1208333.0
# 3  Bungoma     1670570   3024  1670570.0
# 4  Mandera      867457  25942   867457.0
# 5  Turkana      926976  68233   926976.0
# 7    Nyeri      759164   3325   759164.0
# 8  Nairobi     4397073    704  4397073.0

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   County      8 non-null      object
#  1   Population  8 non-null      int32
#  2   Area        8 non-null      int64
#  3   count       8 non-null      float64
# dtypes: float64(1), int32(1), int64(1), object(1)
# memory usage: 288.0+ bytes

# %% [markdown]
# Good book to read: https://jakevdp.github.io/PythonDataScienceHandbook/

# %% [markdown]
# **Syntax**

# %% [raw]
# DataFrame.groupby("column name")

# %%
data.groupby("County")

# %%
cad=pd.read_excel("census area density.xlsx", thousands=",")
cad
# Out:
#     Sub County   Area  Density
# 0    Changamwe   17.7     7457
# 1        Jomvu   36.9     4432
# 2      Kisauni   87.7     3328
# 3       Likoni   40.5     6187
# 4        Mvita   14.6    10543
# ..         ...    ...      ...
# 343   Makadara   11.7    16150
# 344    Mathare    3.0    68941
# 345      Njiru  129.9     4821
# 346    Starehe   20.6    10205
# 347  Westlands   97.5     3167
#
# [348 rows x 3 columns]

# %%
cad.dtypes
# Out:
# Sub County     object
# Area          float64
# Density         int64
# dtype: object

# %%
cad.groupby("Sub County").mean().reset_index()
# Out:
#                  Sub County    Area  Density
# 0           Aberdare Forest  1016.7        0
# 1    Aberdare National Park   716.7        0
# 2                  Ainabkoi   492.9      280
# 3                Athi River   827.2      390
# 4                    Awendo   255.3      459
# ..                      ...     ...      ...
# 336              Wajir West  9042.3       13
# 337             Webuye West   238.9      638
# 338              West Pokot  1854.8       99
# 339               Westlands    97.5     3167
# 340                   Yatta  1062.4      162
#
# [341 rows x 3 columns]

# %%
ph.groupby("County").sum().reset_index().max()
# Out:
# County                    West Pokot
# Average Household Size          78.2
# dtype: object

# %%
ph.groupby("Sub County")

# %% [markdown]
# **EXERCISE**
#
# 1). why the data is not recognising the comma seperated value 130,456.
#
# 3). group the two data using county and subcounty and fine the mean in each.
#
# 4). create a third categorical  column variable called overpopulated to check density,,if density is greater than 3000 it should assign yes if not it should assign yes.
#
# 5). group using the three variables and find mean population in those areas.
#
# 6). change the data types of population ,households from object to integers /float.
#
# 7). Using the two datasets of your choice combine them together using append, concatenate, merge, join(right, left, outer and inner).
